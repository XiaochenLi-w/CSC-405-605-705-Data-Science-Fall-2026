# %% [markdown]
# ## Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Welcom to Python Programming!")
# Out:
# Welcom to Python Programming!

# %% [markdown]
# ## Python Code Execution

# %%
import dis

def demo():
    a = 1
    b = 2
    c = a + b
    print(c)

dis.dis(demo)
# Out:
#   3           RESUME                   0
#
#   4           LOAD_CONST               1 (1)
#               STORE_FAST               0 (a)
#
#   5           LOAD_CONST               2 (2)
#               STORE_FAST               1 (b)
#
#   6           LOAD_FAST_LOAD_FAST      1 (a, b)
#               BINARY_OP                0 (+)
#               STORE_FAST               2 (c)
#
#   7           LOAD_GLOBAL              1 (print + NULL)
#               LOAD_FAST                2 (c)
#               CALL                     1
#               POP_TOP
#               RETURN_CONST             0 (None)

# %% [markdown]
# ## Indentation

# %%
if True:
    print('True')
else:
    print('False')
# Out:
# True

# %%
if True:
    print('True')
else:
 print('False')

# %% [markdown]
# ## Identifiers

# %%
apple = 1
print(apple)
2apple = 2
print(2apple)
# Out:
#   Cell In[6], line 3
#     2apple = 2
#     ^
# SyntaxError: invalid decimal literal

# %%
class = 1
print(sum)
# Out:
#   Cell In[10], line 1
#     class = 1
#           ^
# SyntaxError: invalid syntax

# %%
and =1
print(and)
# Out:
#   Cell In[11], line 1
#     and =1
#     ^
# SyntaxError: invalid syntax

# %%
def or():
print("Hello!")
# Out:
#   Cell In[12], line 1
#     def or():
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Variable Assignment

# %%
name = 'Bob'
number = 12.01
print(name, number)
# Out:
# Bob 12.01

# %%
array = [1, 3, 5, 7, 9]
print(array)
# Out:
# [1, 3, 5, 7, 9]

# %%
name, number, array = 'Bob', 12.01, [1, 3, 5, 7, 9]
print(name, number, array)
# Out:
# Bob 12.01 [1, 3, 5, 7, 9]

# %%
a = b = c = 2
print(a, b, c)
# Out:
# 2 2 2

# %%
a = b = c = 'Same'
print(a, b, c)
# Out:
# Same Same Same

# %% [markdown]
# ## Type of Data

# %%
print(type(name), type(number), type(array))
# Out:
# <class 'str'> <class 'float'> <class 'list'>

# %%
val1 = 1 # Integer
val2 = 2
print(type(val1), type(val2))
# Out:
# <class 'int'> <class 'int'>

# %%
string = 'abcd1234'
print(type(string))
# Out:
# <class 'str'>

# %%
print(string[1:4])
# Out:
# bcd

# %%
string1 = 'hello everyone!'
print(string + string1)
# Out:
# abcd1234hello everyone!

# %%
print(string1 + 'hey!')
# Out:
# hello everyone!hey!

# %%
longlist = [ 'hello', 786, 2.23, 'john', 70]
tinylist = [123, 'john']
print(longlist)
# Out:
# ['hello', 786, 2.23, 'john', 70]

# %%
print(longlist[1:3])
# Out:
# [786, 2.23]

# %%
print(longlist[1:])
# Out:
# [786, 2.23, 'john', 70]

# %%
print(tinylist * 2)
# Out:
# [123, 'john', 123, 'john']

# %%
longtuple = ('hello', 786, 2.23, 'john', 70)
tinytuple = (123, 'John')
print(longtuple)
# Out:
# ('hello', 786, 2.23, 'john', 70)

# %%
print(longtuple[1:3])
# Out:
# (786, 2.23)

# %%
print(longtuple[1:])
# Out:
# (786, 2.23, 'john', 70)

# %%
print(tinytuple * 2)
# Out:
# (123, 'John', 123, 'John')

# %%
longlist[1] = 1000
print(longlist)
# Out:
# ['hello', 1000, 2.23, 'john', 70]

# %%
longtuple[1] = 1000
print(longtuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 longtuple[1] = 1000
#       2 print(longtuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
dict = {}
dict['one'] = "This is one"
dict[2] = "This is two"
print (dict['one'])
print (dict[2])
# Out:
# This is one
# This is two

# %%
print(dict.keys())
# Out:
# dict_keys(['one', 2])

# %%
print(dict.values())
# Out:
# dict_values(['This is one', 'This is two'])

# %%
a = bool(0)
print(type(a))
# Out:
# <class 'bool'>

# %%
if a:
    print('Yes')
else:
    print('No')
# Out:
# No
